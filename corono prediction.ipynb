# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('corona_pred.csv')
dataset
# Out:
#      Col_no      name gender  age travel_history    temp pnemonia  \
# 0         1      tina      F   25             no   97.36       no
# 1         2      mark      M   41            yes   97.45      yes
# 2         3      ravi      M   35             no   99.10       no
# 3         4      rosy      F   62             no  101.40      yes
# 4         5      alex      M   77            yes  101.00       no
# ..      ...       ...    ...  ...            ...     ...      ...
# 114     118     lucky      F    5            yes   99.90      yes
# 115     119  savithri      F   67            yes  100.20      yes
# 116     120  prasanna      F   45             no  102.60      yes
# 117     121   sunitha      F   56             no  100.20      yes
# 118       1     srinu      M   46            yes   97.20       no
#
#     breathing_prob  other health problems corona
# 0               no                      0     no
# 1              yes                      2    yes
# 2              yes                      0     no
# 3               no                      3    yes
# 4              yes                      2    yes
# ..             ...                    ...    ...
# 114            yes                      2    yes
# 115            yes                      1    yes
# 116            yes                      2    yes
# 117            yes                      3    yes
# 118             no                      0     no
#
# [119 rows x 10 columns]

# %%
dataset.isnull().any()
# Out:
# Col_no                   False
# name                     False
# gender                   False
# age                      False
# travel_history           False
# temp                     False
# pnemonia                 False
# breathing_prob           False
# other health problems    False
# corona                   False
# dtype: bool

# %%
cols=['Col_no','name']
dataset= dataset.drop(cols,axis=1)
dataset
# Out:
#     gender  age travel_history    temp pnemonia breathing_prob  \
# 0        F   25             no   97.36       no             no
# 1        M   41            yes   97.45      yes            yes
# 2        M   35             no   99.10       no            yes
# 3        F   62             no  101.40      yes             no
# 4        M   77            yes  101.00       no            yes
# ..     ...  ...            ...     ...      ...            ...
# 114      F    5            yes   99.90      yes            yes
# 115      F   67            yes  100.20      yes            yes
# 116      F   45             no  102.60      yes            yes
# 117      F   56             no  100.20      yes            yes
# 118      M   46            yes   97.20       no             no
#
#      other health problems corona
# 0                        0     no
# 1                        2    yes
# 2                        0     no
# 3                        3    yes
# 4                        2    yes
# ..                     ...    ...
# 114                      2    yes
# 115                      1    yes
# 116                      2    yes
# 117                      3    yes
# 118                      0     no
#
# [119 rows x 8 columns]

# %%
x=dataset.iloc[:,:7].values
x
# Out:
# array([['F', 25, 'no', 97.36, 'no', 'no', 0],
#        ['M', 41, 'yes', 97.45, 'yes', 'yes', 2],
#        ['M', 35, 'no', 99.1, 'no', 'yes', 0],
#        ['F', 62, 'no', 101.4, 'yes', 'no', 3],
#        ['M', 77, 'yes', 101.0, 'no', 'yes', 2],
#        ['M', 22, 'no', 96.0, 'no', 'yes', 0],
#        ['F', 23, 'no', 98.0, 'no', 'no', 1],
#        ['M', 43, 'no', 101.0, 'yes', 'yes', 3],
#        ['M', 74, 'no', 99.6, 'yes', 'yes', 2],
#        ['M', 17, 'yes', 97.0, 'yes', 'yes', 1],
#        ['F', 31, 'yes', 100.0, 'yes', 'yes', 3],
#        ['F', 22, 'yes', 97.0, 'no', 'no', 1],
#        ['M', 49, 'yes', 102.0, 'yes', 'yes', 3],
#        ['M', 21, 'no', 96.0, 'no', 'no', 0],
#        ['F', 49, 'no', 100.0, 'no', 'no', 0],
#        ['M', 12, 'no', 97.6, 'no', 'no', 0],
#        ['M', 40, 'yes', 99.9, 'yes', 'yes', 3],
#        ['F', 20, 'yes', 98.0, 'no', 'no', 1],
#        ['M', 99, 'no', 102.9, 'yes', 'yes', 2],
#        ['M', 45, 'yes', 102.6, 'yes', 'yes', 2],
#        ['F', 25, 'yes', 98.5, 'no', 'no', 1],
#        ['F', 17, 'no', 96.1, 'yes', 'yes', 0],
#        ['M', 32, 'yes', 96.9, 'no', 'no', 1],
#        ['M', 28, 'no', 99.2, 'no', 'no', 1],
#        ['M', 37, 'no', 103.6, 'yes', 'yes', 2],
#        ['F', 9, 'yes', 95.3, 'no', 'no', 1],
#        ['M', 27, 'yes', 102.9, 'yes', 'yes', 3],
#        ['F', 24, 'yes', 98.3, 'no', 'no', 1],
#        ['F', 16, 'no', 99.1, 'no', 'no', 0],
#        ['F', 62, 'yes', 100.2, 'no', 'yes', 2],
#        ['F', 7, 'no', 99.9, 'yes', 'no', 0],
#        ['M', 20, 'no', 97.1, 'no', 'no', 1],
#        ['M', 22, 'yes', 98.2, 'no', 'no', 1],
#        ['F', 15, 'yes', 101.0, 'yes', 'yes', 3],
#        ['F', 10, 'yes', 100.0, 'yes', 'yes', 2],
#        ['F', 27, 'yes', 97.0, 'no', 'no', 1],
#        ['F', 65, 'no', 102.0, 'yes', 'yes', 2],
#        ['F', 4, 'yes', 99.9, 'no', 'yes', 1],
#        ['F', 85, 'yes', 100.0, 'yes', 'yes', 0],
#        ['M', 32, 'yes', 97.0, 'no', 'yes', 1],
#        ['M', 21, 'yes', 99.0, 'no', 'no', 0],
#        ['F', 67, 'yes', 101.0, 'yes', 'yes', 2],
#        ['M', 34, 'no', 97.0, 'no', 'no', 1],
#        ['M', 85, 'yes', 102.6, 'no', 'yes', 3],
#        ['M', 5, 'no', 99.9, 'yes', 'yes', 3],
#        ['M', 66, 'no', 100.0, 'yes', 'yes', 2],
#        ['F', 23, 'no', 98.0, 'yes', 'no', 1],
#        ['F', 18, 'no', 97.0, 'yes', 'no', 0],
#        ['F', 45, 'no', 99.2, 'no', 'yes', 1],
#        ['M', 70, 'yes', 101.3, 'yes', 'yes', 3],
#        ['M', 25, 'yes', 97.2, 'no', 'no', 0],
#        ['M', 51, 'no', 101.8, 'yes', 'yes', 2],
#        ['F', 41, 'yes', 97.1, 'no', 'no', 1],
#        ['M', 65, 'yes', 99.3, 'yes', 'yes', 3],
#        ['M', 74, 'yes', 100.2, 'no', 'no', 3],
#        ['F', 33, 'no', 97.4, 'no', 'no', 0],
#        ['F', 25, 'yes', 98.0, 'no', 'no', 0],
#        ['F', 41, 'no', 96.9, 'no', 'no', 1],
#        ['F', 8, 'no', 101.0, 'yes', 'yes', 2],
#        ['F', 11, 'yes', 97.4, 'no', 'no', 0],
#        ['M', 22, 'no', 98.3, 'no', 'no', 0],
#        ['M', 56, 'no', 99.0, 'no', 'no', 1],
#        ['M', 3, 'yes', 99.9, 'yes', 'yes', 2],
#        ['F', 78, 'yes', 100.3, 'no', 'yes', 1],
#        ['F', 58, 'no', 100.1, 'yes', 'yes', 2],
#        ['F', 32, 'yes', 99.1, 'no', 'no', 2],
#        ['M', 45, 'yes', 98.0, 'no', 'no', 1],
#        ['M', 12, 'no', 97.2, 'no', 'yes', 0],
#        ['F', 25, 'yes', 98.1, 'no', 'no', 0],
#        ['F', 69, 'yes', 99.8, 'yes', 'no', 3],
#        ['M', 68, 'yes', 99.9, 'yes', 'yes', 2],
#        ['M', 54, 'yes', 100.1, 'yes', 'yes', 1],
#        ['M', 21, 'no', 98.5, 'no', 'yes', 0],
#        ['M', 19, 'no', 97.6, 'no', 'yes', 2],
#        ['F', 12, 'yes', 98.1, 'no', 'no', 0],
#        ['M', 4, 'yes', 99.7, 'yes', 'yes', 2],
#        ['M', 45, 'no', 97.3, 'no', 'yes', 1],
#        ['F', 39, 'no', 98.2, 'no', 'no', 0],
#        ['F', 37, 'no', 97.2, 'no', 'no', 0],
#        ['F', 15, 'no', 97.1, 'no', 'no', 1],
#        ['F', 45, 'no', 98.0, 'no', 'no', 1],
#        ['F', 66, 'yes', 100.5, 'yes', 'no', 3],
#        ['M', 36, 'no', 98.7, 'no', 'no', 0],
#        ['M', 76, 'yes', 99.2, 'yes', 'no', 2],
#        ['F', 85, 'yes', 101.0, 'yes', 'no', 3],
#        ['F', 48, 'no', 98.5, 'no', 'no', 1],
#        ['F', 23, 'no', 96.8, 'no', 'no', 0],
#        ['F', 33, 'no', 97.5, 'no', 'no', 0],
#        ['F', 75, 'yes', 98.2, 'yes', 'no', 3],
#        ['M', 65, 'yes', 99.4, 'yes', 'yes', 2],
#        ['M', 41, 'no', 97.1, 'no', 'yes', 1],
#        ['F', 17, 'no', 97.0, 'no', 'no', 0],
#        ['F', 28, 'no', 98.6, 'no', 'no', 0],
#        ['F', 30, 'no', 97.9, 'no', 'no', 1],
#        ['F', 35, 'no', 98.2, 'no', 'yno', 1],
#        ['F', 76, 'no', 102.3, 'yes', 'no', 2],
#        ['F', 37, 'no', 97.2, 'no', 'no', 1],
#        ['M', 55, 'yes', 99.7, 'yes', 'yes', 3],
#        ['M', 24, 'no', 98.2, 'no', 'no', 1],
#        ['M', 41, 'no', 99.1, 'no', 'yes', 0],
#        ['M', 71, 'yes', 99.8, 'yes', 'yes', 2],
#        ['M', 48, 'no', 97.4, 'no', 'no', 0],
#        ['M', 29, 'no', 97.5, 'no', 'no', 1],
#        ['F', 61, 'yes', 101.2, 'yes', 'yes', 3],
#        ['M', 37, 'no', 97.3, 'no', 'no', 1],
#        ['F', 23, 'no', 98.2, 'no', 'no', 1],
#        ['M', 45, 'yes', 100.1, 'yes', 'yes', 3],
#        ['F', 52, 'yes', 102.3, 'yes', 'yes', 2],
#        ['F', 34, 'no', 98.2, 'no', 'no', 0],
#        ['M', 45, 'no', 96.4, 'no', 'no', 1],
#        ['M', 83, 'yes', 99.9, 'yes', 'yes', 2],
#        ['M', 32, 'no', 99.4, 'no', 'no', 0],
#        ['F', 61, 'yes', 101.2, 'yes', 'no', 0],
#        ['F', 20, 'no', 98.4, 'no', 'yes', 0],
#        ['F', 5, 'yes', 99.9, 'yes', 'yes', 2],
#        ['F', 67, 'yes', 100.2, 'yes', 'yes', 1],
#        ['F', 45, 'no', 102.6, 'yes', 'yes', 2],
#        ['F', 56, 'no', 100.2, 'yes', 'yes', 3],
#        ['M', 46, 'yes', 97.2, 'no', 'no', 0]], dtype=object)

# %%
y=dataset.iloc[:,7:].values
y
# Out:
# array([['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
x[:,0]=lb.fit_transform(x[:,0])
x
# Out:
# array([[0, 25, 'no', 97.36, 'no', 'no', 0],
#        [1, 41, 'yes', 97.45, 'yes', 'yes', 2],
#        [1, 35, 'no', 99.1, 'no', 'yes', 0],
#        [0, 62, 'no', 101.4, 'yes', 'no', 3],
#        [1, 77, 'yes', 101.0, 'no', 'yes', 2],
#        [1, 22, 'no', 96.0, 'no', 'yes', 0],
#        [0, 23, 'no', 98.0, 'no', 'no', 1],
#        [1, 43, 'no', 101.0, 'yes', 'yes', 3],
#        [1, 74, 'no', 99.6, 'yes', 'yes', 2],
#        [1, 17, 'yes', 97.0, 'yes', 'yes', 1],
#        [0, 31, 'yes', 100.0, 'yes', 'yes', 3],
#        [0, 22, 'yes', 97.0, 'no', 'no', 1],
#        [1, 49, 'yes', 102.0, 'yes', 'yes', 3],
#        [1, 21, 'no', 96.0, 'no', 'no', 0],
#        [0, 49, 'no', 100.0, 'no', 'no', 0],
#        [1, 12, 'no', 97.6, 'no', 'no', 0],
#        [1, 40, 'yes', 99.9, 'yes', 'yes', 3],
#        [0, 20, 'yes', 98.0, 'no', 'no', 1],
#        [1, 99, 'no', 102.9, 'yes', 'yes', 2],
#        [1, 45, 'yes', 102.6, 'yes', 'yes', 2],
#        [0, 25, 'yes', 98.5, 'no', 'no', 1],
#        [0, 17, 'no', 96.1, 'yes', 'yes', 0],
#        [1, 32, 'yes', 96.9, 'no', 'no', 1],
#        [1, 28, 'no', 99.2, 'no', 'no', 1],
#        [1, 37, 'no', 103.6, 'yes', 'yes', 2],
#        [0, 9, 'yes', 95.3, 'no', 'no', 1],
#        [1, 27, 'yes', 102.9, 'yes', 'yes', 3],
#        [0, 24, 'yes', 98.3, 'no', 'no', 1],
#        [0, 16, 'no', 99.1, 'no', 'no', 0],
#        [0, 62, 'yes', 100.2, 'no', 'yes', 2],
#        [0, 7, 'no', 99.9, 'yes', 'no', 0],
#        [1, 20, 'no', 97.1, 'no', 'no', 1],
#        [1, 22, 'yes', 98.2, 'no', 'no', 1],
#        [0, 15, 'yes', 101.0, 'yes', 'yes', 3],
#        [0, 10, 'yes', 100.0, 'yes', 'yes', 2],
#        [0, 27, 'yes', 97.0, 'no', 'no', 1],
#        [0, 65, 'no', 102.0, 'yes', 'yes', 2],
#        [0, 4, 'yes', 99.9, 'no', 'yes', 1],
#        [0, 85, 'yes', 100.0, 'yes', 'yes', 0],
#        [1, 32, 'yes', 97.0, 'no', 'yes', 1],
#        [1, 21, 'yes', 99.0, 'no', 'no', 0],
#        [0, 67, 'yes', 101.0, 'yes', 'yes', 2],
#        [1, 34, 'no', 97.0, 'no', 'no', 1],
#        [1, 85, 'yes', 102.6, 'no', 'yes', 3],
#        [1, 5, 'no', 99.9, 'yes', 'yes', 3],
#        [1, 66, 'no', 100.0, 'yes', 'yes', 2],
#        [0, 23, 'no', 98.0, 'yes', 'no', 1],
#        [0, 18, 'no', 97.0, 'yes', 'no', 0],
#        [0, 45, 'no', 99.2, 'no', 'yes', 1],
#        [1, 70, 'yes', 101.3, 'yes', 'yes', 3],
#        [1, 25, 'yes', 97.2, 'no', 'no', 0],
#        [1, 51, 'no', 101.8, 'yes', 'yes', 2],
#        [0, 41, 'yes', 97.1, 'no', 'no', 1],
#        [1, 65, 'yes', 99.3, 'yes', 'yes', 3],
#        [1, 74, 'yes', 100.2, 'no', 'no', 3],
#        [0, 33, 'no', 97.4, 'no', 'no', 0],
#        [0, 25, 'yes', 98.0, 'no', 'no', 0],
#        [0, 41, 'no', 96.9, 'no', 'no', 1],
#        [0, 8, 'no', 101.0, 'yes', 'yes', 2],
#        [0, 11, 'yes', 97.4, 'no', 'no', 0],
#        [1, 22, 'no', 98.3, 'no', 'no', 0],
#        [1, 56, 'no', 99.0, 'no', 'no', 1],
#        [1, 3, 'yes', 99.9, 'yes', 'yes', 2],
#        [0, 78, 'yes', 100.3, 'no', 'yes', 1],
#        [0, 58, 'no', 100.1, 'yes', 'yes', 2],
#        [0, 32, 'yes', 99.1, 'no', 'no', 2],
#        [1, 45, 'yes', 98.0, 'no', 'no', 1],
#        [1, 12, 'no', 97.2, 'no', 'yes', 0],
#        [0, 25, 'yes', 98.1, 'no', 'no', 0],
#        [0, 69, 'yes', 99.8, 'yes', 'no', 3],
#        [1, 68, 'yes', 99.9, 'yes', 'yes', 2],
#        [1, 54, 'yes', 100.1, 'yes', 'yes', 1],
#        [1, 21, 'no', 98.5, 'no', 'yes', 0],
#        [1, 19, 'no', 97.6, 'no', 'yes', 2],
#        [0, 12, 'yes', 98.1, 'no', 'no', 0],
#        [1, 4, 'yes', 99.7, 'yes', 'yes', 2],
#        [1, 45, 'no', 97.3, 'no', 'yes', 1],
#        [0, 39, 'no', 98.2, 'no', 'no', 0],
#        [0, 37, 'no', 97.2, 'no', 'no', 0],
#        [0, 15, 'no', 97.1, 'no', 'no', 1],
#        [0, 45, 'no', 98.0, 'no', 'no', 1],
#        [0, 66, 'yes', 100.5, 'yes', 'no', 3],
#        [1, 36, 'no', 98.7, 'no', 'no', 0],
#        [1, 76, 'yes', 99.2, 'yes', 'no', 2],
#        [0, 85, 'yes', 101.0, 'yes', 'no', 3],
#        [0, 48, 'no', 98.5, 'no', 'no', 1],
#        [0, 23, 'no', 96.8, 'no', 'no', 0],
#        [0, 33, 'no', 97.5, 'no', 'no', 0],
#        [0, 75, 'yes', 98.2, 'yes', 'no', 3],
#        [1, 65, 'yes', 99.4, 'yes', 'yes', 2],
#        [1, 41, 'no', 97.1, 'no', 'yes', 1],
#        [0, 17, 'no', 97.0, 'no', 'no', 0],
#        [0, 28, 'no', 98.6, 'no', 'no', 0],
#        [0, 30, 'no', 97.9, 'no', 'no', 1],
#        [0, 35, 'no', 98.2, 'no', 'yno', 1],
#        [0, 76, 'no', 102.3, 'yes', 'no', 2],
#        [0, 37, 'no', 97.2, 'no', 'no', 1],
#        [1, 55, 'yes', 99.7, 'yes', 'yes', 3],
#        [1, 24, 'no', 98.2, 'no', 'no', 1],
#        [1, 41, 'no', 99.1, 'no', 'yes', 0],
#        [1, 71, 'yes', 99.8, 'yes', 'yes', 2],
#        [1, 48, 'no', 97.4, 'no', 'no', 0],
#        [1, 29, 'no', 97.5, 'no', 'no', 1],
#        [0, 61, 'yes', 101.2, 'yes', 'yes', 3],
#        [1, 37, 'no', 97.3, 'no', 'no', 1],
#        [0, 23, 'no', 98.2, 'no', 'no', 1],
#        [1, 45, 'yes', 100.1, 'yes', 'yes', 3],
#        [0, 52, 'yes', 102.3, 'yes', 'yes', 2],
#        [0, 34, 'no', 98.2, 'no', 'no', 0],
#        [1, 45, 'no', 96.4, 'no', 'no', 1],
#        [1, 83, 'yes', 99.9, 'yes', 'yes', 2],
#        [1, 32, 'no', 99.4, 'no', 'no', 0],
#        [0, 61, 'yes', 101.2, 'yes', 'no', 0],
#        [0, 20, 'no', 98.4, 'no', 'yes', 0],
#        [0, 5, 'yes', 99.9, 'yes', 'yes', 2],
#        [0, 67, 'yes', 100.2, 'yes', 'yes', 1],
#        [0, 45, 'no', 102.6, 'yes', 'yes', 2],
#        [0, 56, 'no', 100.2, 'yes', 'yes', 3],
#        [1, 46, 'yes', 97.2, 'no', 'no', 0]], dtype=object)

# %%
x[:,2]=lb.fit_transform(x[:,2])
x[:,4]=lb.fit_transform(x[:,4])
x[:,5]=lb.fit_transform(x[:,5])
x
# Out:
# array([[0, 25, 0, 97.36, 0, 0, 0],
#        [1, 41, 1, 97.45, 1, 1, 2],
#        [1, 35, 0, 99.1, 0, 1, 0],
#        [0, 62, 0, 101.4, 1, 0, 3],
#        [1, 77, 1, 101.0, 0, 1, 2],
#        [1, 22, 0, 96.0, 0, 1, 0],
#        [0, 23, 0, 98.0, 0, 0, 1],
#        [1, 43, 0, 101.0, 1, 1, 3],
#        [1, 74, 0, 99.6, 1, 1, 2],
#        [1, 17, 1, 97.0, 1, 1, 1],
#        [0, 31, 1, 100.0, 1, 1, 3],
#        [0, 22, 1, 97.0, 0, 0, 1],
#        [1, 49, 1, 102.0, 1, 1, 3],
#        [1, 21, 0, 96.0, 0, 0, 0],
#        [0, 49, 0, 100.0, 0, 0, 0],
#        [1, 12, 0, 97.6, 0, 0, 0],
#        [1, 40, 1, 99.9, 1, 1, 3],
#        [0, 20, 1, 98.0, 0, 0, 1],
#        [1, 99, 0, 102.9, 1, 1, 2],
#        [1, 45, 1, 102.6, 1, 1, 2],
#        [0, 25, 1, 98.5, 0, 0, 1],
#        [0, 17, 0, 96.1, 1, 1, 0],
#        [1, 32, 1, 96.9, 0, 0, 1],
#        [1, 28, 0, 99.2, 0, 0, 1],
#        [1, 37, 0, 103.6, 1, 1, 2],
#        [0, 9, 1, 95.3, 0, 0, 1],
#        [1, 27, 1, 102.9, 1, 1, 3],
#        [0, 24, 1, 98.3, 0, 0, 1],
#        [0, 16, 0, 99.1, 0, 0, 0],
#        [0, 62, 1, 100.2, 0, 1, 2],
#        [0, 7, 0, 99.9, 1, 0, 0],
#        [1, 20, 0, 97.1, 0, 0, 1],
#        [1, 22, 1, 98.2, 0, 0, 1],
#        [0, 15, 1, 101.0, 1, 1, 3],
#        [0, 10, 1, 100.0, 1, 1, 2],
#        [0, 27, 1, 97.0, 0, 0, 1],
#        [0, 65, 0, 102.0, 1, 1, 2],
#        [0, 4, 1, 99.9, 0, 1, 1],
#        [0, 85, 1, 100.0, 1, 1, 0],
#        [1, 32, 1, 97.0, 0, 1, 1],
#        [1, 21, 1, 99.0, 0, 0, 0],
#        [0, 67, 1, 101.0, 1, 1, 2],
#        [1, 34, 0, 97.0, 0, 0, 1],
#        [1, 85, 1, 102.6, 0, 1, 3],
#        [1, 5, 0, 99.9, 1, 1, 3],
#        [1, 66, 0, 100.0, 1, 1, 2],
#        [0, 23, 0, 98.0, 1, 0, 1],
#        [0, 18, 0, 97.0, 1, 0, 0],
#        [0, 45, 0, 99.2, 0, 1, 1],
#        [1, 70, 1, 101.3, 1, 1, 3],
#        [1, 25, 1, 97.2, 0, 0, 0],
#        [1, 51, 0, 101.8, 1, 1, 2],
#        [0, 41, 1, 97.1, 0, 0, 1],
#        [1, 65, 1, 99.3, 1, 1, 3],
#        [1, 74, 1, 100.2, 0, 0, 3],
#        [0, 33, 0, 97.4, 0, 0, 0],
#        [0, 25, 1, 98.0, 0, 0, 0],
#        [0, 41, 0, 96.9, 0, 0, 1],
#        [0, 8, 0, 101.0, 1, 1, 2],
#        [0, 11, 1, 97.4, 0, 0, 0],
#        [1, 22, 0, 98.3, 0, 0, 0],
#        [1, 56, 0, 99.0, 0, 0, 1],
#        [1, 3, 1, 99.9, 1, 1, 2],
#        [0, 78, 1, 100.3, 0, 1, 1],
#        [0, 58, 0, 100.1, 1, 1, 2],
#        [0, 32, 1, 99.1, 0, 0, 2],
#        [1, 45, 1, 98.0, 0, 0, 1],
#        [1, 12, 0, 97.2, 0, 1, 0],
#        [0, 25, 1, 98.1, 0, 0, 0],
#        [0, 69, 1, 99.8, 1, 0, 3],
#        [1, 68, 1, 99.9, 1, 1, 2],
#        [1, 54, 1, 100.1, 1, 1, 1],
#        [1, 21, 0, 98.5, 0, 1, 0],
#        [1, 19, 0, 97.6, 0, 1, 2],
#        [0, 12, 1, 98.1, 0, 0, 0],
#        [1, 4, 1, 99.7, 1, 1, 2],
#        [1, 45, 0, 97.3, 0, 1, 1],
#        [0, 39, 0, 98.2, 0, 0, 0],
#        [0, 37, 0, 97.2, 0, 0, 0],
#        [0, 15, 0, 97.1, 0, 0, 1],
#        [0, 45, 0, 98.0, 0, 0, 1],
#        [0, 66, 1, 100.5, 1, 0, 3],
#        [1, 36, 0, 98.7, 0, 0, 0],
#        [1, 76, 1, 99.2, 1, 0, 2],
#        [0, 85, 1, 101.0, 1, 0, 3],
#        [0, 48, 0, 98.5, 0, 0, 1],
#        [0, 23, 0, 96.8, 0, 0, 0],
#        [0, 33, 0, 97.5, 0, 0, 0],
#        [0, 75, 1, 98.2, 1, 0, 3],
#        [1, 65, 1, 99.4, 1, 1, 2],
#        [1, 41, 0, 97.1, 0, 1, 1],
#        [0, 17, 0, 97.0, 0, 0, 0],
#        [0, 28, 0, 98.6, 0, 0, 0],
#        [0, 30, 0, 97.9, 0, 0, 1],
#        [0, 35, 0, 98.2, 0, 2, 1],
#        [0, 76, 0, 102.3, 1, 0, 2],
#        [0, 37, 0, 97.2, 0, 0, 1],
#        [1, 55, 1, 99.7, 1, 1, 3],
#        [1, 24, 0, 98.2, 0, 0, 1],
#        [1, 41, 0, 99.1, 0, 1, 0],
#        [1, 71, 1, 99.8, 1, 1, 2],
#        [1, 48, 0, 97.4, 0, 0, 0],
#        [1, 29, 0, 97.5, 0, 0, 1],
#        [0, 61, 1, 101.2, 1, 1, 3],
#        [1, 37, 0, 97.3, 0, 0, 1],
#        [0, 23, 0, 98.2, 0, 0, 1],
#        [1, 45, 1, 100.1, 1, 1, 3],
#        [0, 52, 1, 102.3, 1, 1, 2],
#        [0, 34, 0, 98.2, 0, 0, 0],
#        [1, 45, 0, 96.4, 0, 0, 1],
#        [1, 83, 1, 99.9, 1, 1, 2],
#        [1, 32, 0, 99.4, 0, 0, 0],
#        [0, 61, 1, 101.2, 1, 0, 0],
#        [0, 20, 0, 98.4, 0, 1, 0],
#        [0, 5, 1, 99.9, 1, 1, 2],
#        [0, 67, 1, 100.2, 1, 1, 1],
#        [0, 45, 0, 102.6, 1, 1, 2],
#        [0, 56, 0, 100.2, 1, 1, 3],
#        [1, 46, 1, 97.2, 0, 0, 0]], dtype=object)

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x=sc.fit_transform(x)
# x

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=100)

# %%
x_train
# Out:
# array([[1, 45, 0, 97.3, 0, 1, 1],
#        [1, 21, 1, 99.0, 0, 0, 0],
#        [1, 25, 1, 97.2, 0, 0, 0],
#        [1, 83, 1, 99.9, 1, 1, 2],
#        [0, 41, 0, 96.9, 0, 0, 1],
#        [0, 69, 1, 99.8, 1, 0, 3],
#        [1, 34, 0, 97.0, 0, 0, 1],
#        [0, 75, 1, 98.2, 1, 0, 3],
#        [1, 46, 1, 97.2, 0, 0, 0],
#        [0, 20, 1, 98.0, 0, 0, 1],
#        [1, 32, 0, 99.4, 0, 0, 0],
#        [1, 21, 0, 98.5, 0, 1, 0],
#        [0, 67, 1, 100.2, 1, 1, 1],
#        [1, 68, 1, 99.9, 1, 1, 2],
#        [0, 25, 0, 97.36, 0, 0, 0],
#        [1, 99, 0, 102.9, 1, 1, 2],
#        [1, 5, 0, 99.9, 1, 1, 3],
#        [0, 85, 1, 100.0, 1, 1, 0],
#        [1, 32, 1, 97.0, 0, 1, 1],
#        [0, 66, 1, 100.5, 1, 0, 3],
#        [0, 61, 1, 101.2, 1, 0, 0],
#        [0, 7, 0, 99.9, 1, 0, 0],
#        [0, 25, 1, 98.0, 0, 0, 0],
#        [0, 28, 0, 98.6, 0, 0, 0],
#        [0, 52, 1, 102.3, 1, 1, 2],
#        [0, 78, 1, 100.3, 0, 1, 1],
#        [1, 45, 1, 102.6, 1, 1, 2],
#        [0, 76, 0, 102.3, 1, 0, 2],
#        [1, 54, 1, 100.1, 1, 1, 1],
#        [0, 33, 0, 97.4, 0, 0, 0],
#        [1, 37, 0, 97.3, 0, 0, 1],
#        [1, 56, 0, 99.0, 0, 0, 1],
#        [0, 32, 1, 99.1, 0, 0, 2],
#        [0, 18, 0, 97.0, 1, 0, 0],
#        [1, 70, 1, 101.3, 1, 1, 3],
#        [1, 43, 0, 101.0, 1, 1, 3],
#        [0, 45, 0, 102.6, 1, 1, 2],
#        [0, 11, 1, 97.4, 0, 0, 0],
#        [0, 17, 0, 97.0, 0, 0, 0],
#        [1, 76, 1, 99.2, 1, 0, 2],
#        [1, 21, 0, 96.0, 0, 0, 0],
#        [1, 41, 1, 97.45, 1, 1, 2],
#        [1, 20, 0, 97.1, 0, 0, 1],
#        [1, 77, 1, 101.0, 0, 1, 2],
#        [0, 24, 1, 98.3, 0, 0, 1],
#        [1, 35, 0, 99.1, 0, 1, 0],
#        [0, 23, 0, 96.8, 0, 0, 0],
#        [0, 30, 0, 97.9, 0, 0, 1],
#        [1, 17, 1, 97.0, 1, 1, 1],
#        [1, 40, 1, 99.9, 1, 1, 3],
#        [0, 8, 0, 101.0, 1, 1, 2],
#        [1, 22, 0, 98.3, 0, 0, 0],
#        [1, 71, 1, 99.8, 1, 1, 2],
#        [1, 12, 0, 97.6, 0, 0, 0],
#        [0, 56, 0, 100.2, 1, 1, 3],
#        [0, 10, 1, 100.0, 1, 1, 2],
#        [0, 49, 0, 100.0, 0, 0, 0],
#        [0, 34, 0, 98.2, 0, 0, 0],
#        [1, 45, 1, 98.0, 0, 0, 1],
#        [1, 65, 1, 99.3, 1, 1, 3],
#        [1, 24, 0, 98.2, 0, 0, 1],
#        [0, 41, 1, 97.1, 0, 0, 1],
#        [0, 35, 0, 98.2, 0, 2, 1],
#        [0, 31, 1, 100.0, 1, 1, 3],
#        [0, 45, 0, 99.2, 0, 1, 1],
#        [0, 15, 0, 97.1, 0, 0, 1],
#        [0, 33, 0, 97.5, 0, 0, 0],
#        [0, 61, 1, 101.2, 1, 1, 3],
#        [1, 12, 0, 97.2, 0, 1, 0],
#        [1, 37, 0, 103.6, 1, 1, 2],
#        [1, 74, 0, 99.6, 1, 1, 2]], dtype=object)

# %%
y_train
# Out:
# array([['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes']], dtype=object)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#pipe.fit(x_train,y_train)

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array(['yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes',
#        'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes',
#        'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no'], dtype=object)

# %%
y_test
# Out:
# array([['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['yes'],
#        ['no'],
#        ['yes'],
#        ['no'],
#        ['no'],
#        ['no']], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9791666666666666

# %%
from sklearn.tree import DecisionTreeClassifier
dtc= DecisionTreeClassifier(criterion='entropy',random_state=0)
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
y_pred2=lr.predict(x_test)
y_pred2
# Out:
# array(['yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes',
#        'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes',
#        'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred2)
# Out:
# 0.9791666666666666

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(random_state=0,n_estimators=10)
rf.fit(x_train,y_train)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred3=lr.predict(x_test)
y_pred3
# Out:
# array(['yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes',
#        'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes',
#        'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred3)
# Out:
# 0.9791666666666666
